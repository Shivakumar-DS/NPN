# %%
import pandas as pd
import numpy as np

# %%
football_data = pd.read_csv('C:/Users/tin2383/Desktop/New folder/Laliga.csv')

# %%
football_data.set_index('Pos')
# Out:
#                  Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1         Real Madrid       86   4385        2762     1647        552
# 2           Barcelona       86   4262        2762     1581        573
# 3     Atletico Madrid       80   3442        2614     1241        598
# 4            Valencia       82   3386        2664     1187        616
# 5     Athletic Bilbao       86   3368        2762     1209        633
# ..                ...      ...    ...         ...      ...        ...
# 57              Xerez        1     34          38        8         10
# 58             Condal        1     22          30        7          8
# 59    Atletico Tetuan        1     19          30        7          5
# 60   Cultural Leonesa        1     14          30        5          4
# 61             Girona        1      -           -        -          -
#
#     GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# ...

# %%
football_data.head()
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp  BestPosition
# ...

# %%
football_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pos            61 non-null     int64
#  1   Team           61 non-null     object
#  2   Seasons        61 non-null     int64
#  3   Points         61 non-null     object
#  4   GamesPlayed    61 non-null     object
#  5   GamesWon       61 non-null     object
#  6   GamesDrawn     61 non-null     object
#  7   GamesLost      61 non-null     object
#  8   GoalsFor       61 non-null     object
#  9   GoalsAgainst   61 non-null     object
#  10  Champion       61 non-null     object
#  11  Runner-up      61 non-null     object
#  12  Third          61 non-null     object
#  13  Fourth         61 non-null     object
#  14  Fifth          61 non-null     object
#  15  Sixth          61 non-null     object
#  16  T              61 non-null     object
# ...

# %%
football_data.replace('-',np.nan, inplace = True)
football_data = football_data.fillna(0)

# %%
football_data.columns.tolist()
# Out:
# ['Pos',
#  'Team',
#  'Seasons',
#  'Points',
#  'GamesPlayed',
#  'GamesWon',
#  'GamesDrawn',
#  'GamesLost',
#  'GoalsFor',
#  'GoalsAgainst',
#  'Champion',
#  'Runner-up',
#  'Third',
#  'Fourth',
#  'Fifth',
#  'Sixth',
#  'T',
#  'Debut',
#  'Since/LastApp',
#  'BestPosition']

# %%
football_data['Debut'] = football_data['Debut'].astype(str).str[:4].astype(int)
football_data_new = football_data[football_data['Debut'].between(1930, 1980)]
football_data_new['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %%
football_data['Points'] = football_data['Points'].astype(float)
football_data.sort_values(by='Points',ascending=False).head()
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86  4385.0        2762     1647        552
# 1    2        Barcelona       86  4262.0        2762     1581        573
# 2    3  Atletico Madrid       80  3442.0        2614     1241        598
# 3    4         Valencia       82  3386.0        2664     1187        616
# 4    5  Athletic Bilbao       86  3368.0        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T  Debut Since/LastApp  BestPosition
# ...

# %%
def goal_difference(df, column1, column2) :
    df['Goal_differences'] = df[column1].astype(float) - df[column2].astype(float)
    return df['Team'], df['Goal_differences']

# %%
team, goal_diff = goal_difference(football_data,'GoalsFor','GoalsAgainst')
print(team, goal_diff)
# Out:
# 0          Real Madrid
# 1            Barcelona
# 2      Atletico Madrid
# 3             Valencia
# 4      Athletic Bilbao
#             ...
# 56               Xerez
# 57              Condal
# 58     Atletico Tetuan
# 59    Cultural Leonesa
# 60              Girona
# Name: Team, Length: 61, dtype: object 0     2807.0
# 1     2786.0
# 2     1225.0
# 3      929.0
# 4      931.0
#        ...
# 56     -28.0
# 57     -20.0
# 58     -34.0
# 59     -31.0
# 60       0.0
# Name: Goal_differences, Length: 61, dtype: float64

# %%
football_data.head(1)
# Out:
#    Pos         Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1  Real Madrid       86  4385.0        2762     1647        552
#
#   GamesLost GoalsFor GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth   T  \
# 0       563     5947         3140  ...        23     8      8     3     4  79
#
#   Debut  Since/LastApp BestPosition  Goal_differences
# 0  1929           1929            1            2807.0
#
# [1 rows x 21 columns]

# %%
football_data.tail(1)
# Out:
#     Pos    Team  Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# 60   61  Girona        1     0.0           0        0          0         0
#
#    GoalsFor GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth  T Debut  \
# 60        0            0  ...         0     0      0     0     0  0  2017
#
#     Since/LastApp BestPosition  Goal_differences
# 60        2017-18            9               0.0
#
# [1 rows x 21 columns]

# %%
def goal_difference(df, column1, column2) :
    df['Goal_differences'] = df[column1].astype(float) - df[column2].astype(float)
    return df['Team'], df['Goal_differences'], max(df['Goal_differences']),min(df['Goal_differences'])

# %%
a, b, c, d = goal_difference(football_data,'GoalsFor','GoalsAgainst')
[a,b,c,d]
# Out:
# [0          Real Madrid
#  1            Barcelona
#  2      Atletico Madrid
#  3             Valencia
#  4      Athletic Bilbao
#              ...
#  56               Xerez
#  57              Condal
#  58     Atletico Tetuan
#  59    Cultural Leonesa
#  60              Girona
#  Name: Team, Length: 61, dtype: object,
#  0     2807.0
#  1     2786.0
#  2     1225.0
#  3      929.0
#  4      931.0
#         ...
#  56     -28.0
#  57     -20.0
#  58     -34.0
#  59     -31.0
#  60       0.0
#  Name: Goal_differences, Length: 61, dtype: float64,
#  2807.0,
#  -525.0]

# %%
football_data['GamesWon'] = football_data.GamesWon.astype(float)
football_data['GamesPlayed'] = football_data.GamesPlayed.astype(float)
football_data['WinningPercent'] = (football_data.iloc[:,5]/football_data.iloc[:,4])*100
football_data
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0     1       Real Madrid       86  4385.0       2762.0    1647.0        552
# 1     2         Barcelona       86  4262.0       2762.0    1581.0        573
# 2     3   Atletico Madrid       80  3442.0       2614.0    1241.0        598
# 3     4          Valencia       82  3386.0       2664.0    1187.0        616
# 4     5   Athletic Bilbao       86  3368.0       2762.0    1209.0        633
# ..  ...               ...      ...     ...          ...       ...        ...
# 56   57             Xerez        1    34.0         38.0       8.0         10
# 57   58            Condal        1    22.0         30.0       7.0          8
# 58   59   Atletico Tetuan        1    19.0         30.0       7.0          5
# 59   60  Cultural Leonesa        1    14.0         30.0       5.0          4
# 60   61            Girona        1     0.0          0.0       0.0          0
#
# ...

# %%
football_data.groupby(football_data.iloc[:,19]).sum()
# Out:
#               Pos  Seasons   Points  GamesPlayed  GamesWon  Debut  \
# BestPosition
# 1              50      659  27933.0      21532.0    9888.0  17383
# 2              79      195   6904.0       6614.0    2255.0   9761
# 3              89      154   5221.0       4936.0    1732.0   7751
# 4             125      191   6563.0       6497.0    2097.0  11655
# 5             115       63   1884.0       2082.0     624.0   7817
# 6             158       62   2113.0       2052.0     624.0   9767
# 7             190       38   1186.0       1335.0     382.0   9862
# 8             154       31   1134.0       1120.0     319.0   7891
# 9             107        4     96.0        114.0      26.0   4007
# 10            186       13    450.0        450.0     134.0   7932
# 11             28       18    445.0        586.0     145.0   1940
# 12             74       18    511.0        652.0     163.0   3948
# 14             51        3     71.0         90.0      29.0   1953
# ...
